# %%
import pandas as pd
import numpy as np
import os

# %%
car_data = pd.read_excel("Almaty_vv2.xlsx")

# %%
car_data
# Out:
#         City        Mark                  Model     Price  Year          Body  \
# 0     Алматы      Toyota                Avensis   4200000  2003         седан
# 1     Алматы  Mitsubishi                 Delica  12500000  2006  микроавтобус
# 2     Алматы    Infiniti                   QX80  28050000  2018   внедорожник
# 3     Алматы      Nissan                 Patrol  11500000  2012   внедорожник
# 4     Алматы         ВАЗ  (Lada)\tLargus\tCross   4800000  2019       минивэн
# ...      ...         ...                    ...       ...   ...           ...
# 8670  Алматы         ВАЗ  (Lada)\t2170\t(седан)   2000000  2015         седан
# 8671  Алматы       Dodge                Charger   3300000  2009         седан
# 8672  Алматы       Dodge                 Magnum   2900000  2008     универсал
# 8673  Алматы    Chrysler                   300C   2900000  2009         седан
# 8674  Алматы   Chevrolet                  Astro   3400000  2003       минивэн
#
#       EngineSize FuelType GearboxType  Mileage        Color
# 0            2.0   бензин     автомат   200000  серебристый
# 1            3.0   бензин     автомат   180000  серебристый
# 2            5.6   бензин     автомат    22000        белый
# 3            5.6   бензин     автомат   105000        белый
# 4            1.6   бензин    механика    90000       черный
# ...          ...      ...         ...      ...          ...
# 8670         6.0   бензин    механика    85000        белый
# 8671         3.5   бензин     автомат    73000       черный
# 8672         5.7   бензин     автомат    73000       черный
# 8673         3.5   бензин     автомат    72000       черный
# 8674         4.3   бензин     автомат    81000        белый
#
# [8675 rows x 11 columns]

# %%
Random_forest_data = pd.read_excel("Random_forest.xlsx")
Random_forest_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  predictions
# 1727         купе    механика   350350  серебристый       2800000    2699000.0
# 1728       фургон    механика   120000        белый       8499999    8044700.0
# 1729  внедорожник     автомат   263000        белый      14600000   13250000.0
# 1730  внедорожник     автомат   222128       черный      12820000   13095000.0
# 1731         купе   типтроник   100000  серебристый       4900000    5550000.0

# %%
Random_forest_data.shape
# Out:
# (1732, 12)

# %%
value = 0.13

# %%
Random_forest_data_normal = Random_forest_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)") 
Random_forest_data_normal
# Out:
#       car_id        Mark          Model  Year  EngineSize     FuelType  \
# 2       5268  Volkswagen           Golf  1997         1.8       бензин
# 3       7910      Subaru        Tribeca  2007         3.6       бензин
# 4       3182      Daewoo          Nexia  2013         1.5       бензин
# 7       3236      Nissan        Qashqai  2007         2.0       бензин
# 8       5989  Volkswagen         Passat  1992         1.8       бензин
# ...      ...         ...            ...   ...         ...          ...
# 1726    3796      Toyota  Land\tCruiser  2012         4.6       бензин
# 1727    3847         BMW            318  2002         1.9       бензин
# 1728    8630         ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003      Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902      Nissan         Patrol  2013         5.6       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  predictions
# 2         хэтчбек    механика   240000        синий       1700000    1835000.0
# 3       кроссовер     автомат   265983        белый       5250000    5839000.0
# 4           седан    механика   190000        белый       1640000    1760000.0
# 7       кроссовер    вариатор   240550   коричневый       4620000    4565000.0
# 8       универсал    механика   290000     бордовый       1550000    1395400.5
# ...           ...         ...      ...          ...           ...          ...
# 1726  внедорожник     автомат   145000       черный      20800000   21515000.0
# 1727         купе    механика   350350  серебристый       2800000    2699000.0
# 1728       фургон    механика   120000        белый       8499999    8044700.0
# 1729  внедорожник     автомат   263000        белый      14600000   13250000.0
# 1730  внедорожник     автомат   222128       черный      12820000   13095000.0
#
# [948 rows x 12 columns]

# %%
Random_forest_data_notnormal = Random_forest_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
Random_forest_data_notnormal
# Out:
#       car_id        Mark               Model  Year  EngineSize FuelType  \
# 0       2527        Land   Rover\tFreelander  2014         2.0   бензин
# 1       6141      Toyota             Corolla  2011         1.6   бензин
# 5       3285     Porsche             Cayenne  2008         4.8   бензин
# 6       8576      Toyota               HiAce  2012         2.7   бензин
# 9       1696     Hyundai               Coupe  2004         2.0   бензин
# ...      ...         ...                 ...   ...         ...      ...
# 1719    8181      Toyota       Land\tCruiser  2015         4.6   бензин
# 1720    3133         ВАЗ  (Lada)\t2121\tНива  2004         1.7   бензин
# 1723    8545  Mitsubishi              Galant  2005         2.4   бензин
# 1724     526  Volkswagen         Transporter  2007         2.5   дизель
# 1731     313         Kia        Cerato\tKoup  2012         2.0   бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 1            седан     автомат   137500        белый       5400000
# 5        кроссовер   типтроник   109000      голубой       7600000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 9             купе     автомат   155000      красный       2900000
# ...            ...         ...      ...          ...           ...
# 1719   внедорожник     автомат    49700        белый      32500000
# 1720   внедорожник    механика   170000        белый       1700000
# 1723         седан     автомат   429655        серый       2500000
# 1724       минивэн    механика   173000        белый       8000000
# 1731          купе   типтроник   100000  серебристый       4900000
#
#       predictions
# 0      13990000.0
# 1       6225000.0
# 5       9310000.0
# 6      10178998.0
# 9       3335000.0
# ...           ...
# 1719   24590000.0
# 1720    1069555.3
# 1723    4304000.0
# 1724    5549000.0
# 1731    5550000.0
#
# [782 rows x 12 columns]

# %%
XGboost_data = pd.read_excel("XGBoost.xlsx")
XGboost_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  predictions
# 1727         купе    механика   350350  серебристый       2800000   2720490.75
# 1728       фургон    механика   120000        белый       8499999   6916988.00
# 1729  внедорожник     автомат   263000        белый      14600000  13583774.00
# 1730  внедорожник     автомат   222128       черный      12820000  14961265.00
# 1731         купе   типтроник   100000  серебристый       4900000   6880113.50

# %%
XGboost_data.shape
# Out:
# (1732, 12)

# %%
XGboost_data_normal = XGboost_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)")
XGboost_data_normal
# Out:
#       car_id        Mark               Model  Year  EngineSize     FuelType  \
# 1       6141      Toyota             Corolla  2011         1.6       бензин
# 2       5268  Volkswagen                Golf  1997         1.8       бензин
# 3       7910      Subaru             Tribeca  2007         3.6       бензин
# 4       3182      Daewoo               Nexia  2013         1.5       бензин
# 7       3236      Nissan             Qashqai  2007         2.0       бензин
# ...      ...         ...                 ...   ...         ...          ...
# 1720    3133         ВАЗ  (Lada)\t2121\tНива  2004         1.7       бензин
# 1722     322      Toyota               Camry  2003         2.4       бензин
# 1726    3796      Toyota       Land\tCruiser  2012         4.6       бензин
# 1727    3847         BMW                 318  2002         1.9       бензин
# 1729    5003      Toyota       Land\tCruiser  2008         4.7   газ-бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1           седан     автомат   137500        белый       5400000
# 2         хэтчбек    механика   240000        синий       1700000
# 3       кроссовер     автомат   265983        белый       5250000
# 4           седан    механика   190000        белый       1640000
# 7       кроссовер    вариатор   240550   коричневый       4620000
# ...           ...         ...      ...          ...           ...
# 1720  внедорожник    механика   170000        белый       1700000
# 1722        седан     автомат   233000        белый       4500000
# 1726  внедорожник     автомат   145000       черный      20800000
# 1727         купе    механика   350350  серебристый       2800000
# 1729  внедорожник     автомат   263000        белый      14600000
#
#        predictions
# 1     5.460000e+06
# 2     1.817381e+06
# 3     5.880989e+06
# 4     1.612158e+06
# 7     4.460375e+06
# ...            ...
# 1720  1.918292e+06
# 1722  4.362805e+06
# 1726  1.944791e+07
# 1727  2.720491e+06
# 1729  1.358377e+07
#
# [944 rows x 12 columns]

# %%
XGboost_data_notnormal = XGboost_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
XGboost_data_notnormal
# Out:
#       car_id        Mark              Model  Year  EngineSize FuelType  \
# 0       2527        Land  Rover\tFreelander  2014         2.0   бензин
# 5       3285     Porsche            Cayenne  2008         4.8   бензин
# 6       8576      Toyota              HiAce  2012         2.7   бензин
# 8       5989  Volkswagen             Passat  1992         1.8   бензин
# 10      1552      Suzuki      Grand\tVitara  2004         2.0   бензин
# ...      ...         ...                ...   ...         ...      ...
# 1724     526  Volkswagen        Transporter  2007         2.5   дизель
# 1725    6566     Hyundai            Genesis  2019         3.3   бензин
# 1728    8630         ГАЗ       ГАЗель\tNEXT  2018         2.7   бензин
# 1730    4902      Nissan             Patrol  2013         5.6   бензин
# 1731     313         Kia       Cerato\tKoup  2012         2.0   бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 5        кроссовер   типтроник   109000      голубой       7600000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 8        универсал    механика   290000     бордовый       1550000
# 10     внедорожник     автомат   212056   золотистый       3599000
# ...            ...         ...      ...          ...           ...
# 1724       минивэн    механика   173000        белый       8000000
# 1725         седан     автомат    47644       черный      14500000
# 1728        фургон    механика   120000        белый       8499999
# 1730   внедорожник     автомат   222128       черный      12820000
# 1731          купе   типтроник   100000  серебристый       4900000
#
#       predictions
# 0      14644404.0
# 5       8628735.0
# 6      10275888.0
# 8       1024011.5
# 10      4099111.0
# ...           ...
# 1724    4772302.0
# 1725   10707120.0
# 1728    6916988.0
# 1730   14961265.0
# 1731    6880113.5
#
# [788 rows x 12 columns]

# %%
Knn_data = pd.read_excel("KNN.xlsx")
Knn_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1727         купе    механика   350350  серебристый       2800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 1727  2.550000e+06
# 1728  4.888667e+06
# 1729  4.385714e+06
# 1730  2.780000e+06
# 1731  6.457143e+06

# %%
Knn_data.shape
# Out:
# (1732, 12)

# %%
Knn_data_normal = Knn_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)")
Knn_data_normal
# Out:
#       car_id        Mark          Model  Year  EngineSize FuelType  \
# 1       6141      Toyota        Corolla  2011         1.6   бензин
# 11      2317      Toyota          Camry  2017         2.5   бензин
# 14      2416      Toyota          Yaris  2011         1.5   бензин
# 17      4369      Subaru       Forester  2014         2.5   бензин
# 23      1243      Subaru       Forester  2014         2.5   бензин
# ...      ...         ...            ...   ...         ...      ...
# 1666    7787      Toyota  Land\tCruiser  2004         4.7   бензин
# 1672    8443         BMW            530  2008         3.0   бензин
# 1709    1885      Toyota  Land\tCruiser  1999         4.2   дизель
# 1723    8545  Mitsubishi         Galant  2005         2.4   бензин
# 1727    3847         BMW            318  2002         1.9   бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1           седан     автомат   137500        белый       5400000
# 11          седан     автомат    19000       черный      13300000
# 14          седан     автомат   170000        белый       5000000
# 17      кроссовер     автомат   107000        белый       7200000
# 23      кроссовер    вариатор   103000        белый       9300000
# ...           ...         ...      ...          ...           ...
# 1666  внедорожник     автомат   280342       черный       8250000
# 1672        седан     автомат   178000        белый       6188000
# 1709  внедорожник     автомат   290000  серебристый       4700000
# 1723        седан     автомат   429655        серый       2500000
# 1727         купе    механика   350350  серебристый       2800000
#
#        predictions
# 1     4.870000e+06
# 11    1.271714e+07
# 14    5.640000e+06
# 17    7.042857e+06
# 23    8.228571e+06
# ...            ...
# 1666  8.357143e+06
# 1672  5.732857e+06
# 1709  4.491286e+06
# 1723  2.574286e+06
# 1727  2.550000e+06
#
# [256 rows x 12 columns]

# %%
Knn_data_notnormal = Knn_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
Knn_data_notnormal
# Out:
#       car_id        Mark              Model  Year  EngineSize     FuelType  \
# 0       2527        Land  Rover\tFreelander  2014         2.0       бензин
# 2       5268  Volkswagen               Golf  1997         1.8       бензин
# 3       7910      Subaru            Tribeca  2007         3.6       бензин
# 4       3182      Daewoo              Nexia  2013         1.5       бензин
# 5       3285     Porsche            Cayenne  2008         4.8       бензин
# ...      ...         ...                ...   ...         ...          ...
# 1726    3796      Toyota      Land\tCruiser  2012         4.6       бензин
# 1728    8630         ГАЗ       ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003      Toyota      Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902      Nissan             Patrol  2013         5.6       бензин
# 1731     313         Kia       Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 0       кроссовер     автомат    59000        синий       9700000
# 2         хэтчбек    механика   240000        синий       1700000
# 3       кроссовер     автомат   265983        белый       5250000
# 4           седан    механика   190000        белый       1640000
# 5       кроссовер   типтроник   109000      голубой       7600000
# ...           ...         ...      ...          ...           ...
# 1726  внедорожник     автомат   145000       черный      20800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 0     1.645000e+07
# 2     5.735714e+06
# 3     3.398571e+06
# 4     5.321429e+06
# 5     1.279857e+07
# ...            ...
# 1726  9.550000e+06
# 1728  4.888667e+06
# 1729  4.385714e+06
# 1730  2.780000e+06
# 1731  6.457143e+06
#
# [1476 rows x 12 columns]

# %%
Ridge_data = pd.read_excel("Ridge.xlsx")
Ridge_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1727         купе    механика   350350  серебристый       2800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 1727  2.604463e+06
# 1728  1.051789e+07
# 1729  1.453720e+07
# 1730  2.015379e+07
# 1731  8.158161e+06

# %%
Ridge_data.shape
# Out:
# (1732, 12)

# %%
Ridge_data_normal = Ridge_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)")
Ridge_data_normal
# Out:
#       car_id     Mark              Model  Year  EngineSize     FuelType  \
# 0       2527     Land  Rover\tFreelander  2014         2.0       бензин
# 1       6141   Toyota            Corolla  2011         1.6       бензин
# 6       8576   Toyota              HiAce  2012         2.7       бензин
# 14      2416   Toyota              Yaris  2011         1.5       бензин
# 26      4663   Nissan            X-Trail  2016         2.0       бензин
# ...      ...      ...                ...   ...         ...          ...
# 1716     341   Toyota             Sienna  2010         2.7       бензин
# 1718    8169   Toyota            Corolla  2019         1.6       бензин
# 1725    6566  Hyundai            Genesis  2019         3.3       бензин
# 1727    3847      BMW                318  2002         1.9       бензин
# 1729    5003   Toyota      Land\tCruiser  2008         4.7   газ-бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 1            седан     автомат   137500        белый       5400000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 14           седан     автомат   170000        белый       5000000
# 26       кроссовер     автомат    70000       черный      10400000
# ...            ...         ...      ...          ...           ...
# 1716       минивэн     автомат   100000  серебристый       8500000
# 1718         седан   типтроник    20000  серебристый       9100000
# 1725         седан     автомат    47644       черный      14500000
# 1727          купе    механика   350350  серебристый       2800000
# 1729   внедорожник     автомат   263000        белый      14600000
#
#        predictions
# 0     9.729345e+06
# 1     5.078495e+06
# 6     9.319268e+06
# 14    4.437916e+06
# 26    1.055599e+07
# ...            ...
# 1716  9.065126e+06
# 1718  8.806388e+06
# 1725  1.440193e+07
# 1727  2.604463e+06
# 1729  1.453720e+07
#
# [387 rows x 12 columns]

# %%
Ridge_data_notnormal = Knn_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
Ridge_data_notnormal
# Out:
#       car_id        Mark              Model  Year  EngineSize     FuelType  \
# 0       2527        Land  Rover\tFreelander  2014         2.0       бензин
# 2       5268  Volkswagen               Golf  1997         1.8       бензин
# 3       7910      Subaru            Tribeca  2007         3.6       бензин
# 4       3182      Daewoo              Nexia  2013         1.5       бензин
# 5       3285     Porsche            Cayenne  2008         4.8       бензин
# ...      ...         ...                ...   ...         ...          ...
# 1726    3796      Toyota      Land\tCruiser  2012         4.6       бензин
# 1728    8630         ГАЗ       ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003      Toyota      Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902      Nissan             Patrol  2013         5.6       бензин
# 1731     313         Kia       Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 0       кроссовер     автомат    59000        синий       9700000
# 2         хэтчбек    механика   240000        синий       1700000
# 3       кроссовер     автомат   265983        белый       5250000
# 4           седан    механика   190000        белый       1640000
# 5       кроссовер   типтроник   109000      голубой       7600000
# ...           ...         ...      ...          ...           ...
# 1726  внедорожник     автомат   145000       черный      20800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 0     1.645000e+07
# 2     5.735714e+06
# 3     3.398571e+06
# 4     5.321429e+06
# 5     1.279857e+07
# ...            ...
# 1726  9.550000e+06
# 1728  4.888667e+06
# 1729  4.385714e+06
# 1730  2.780000e+06
# 1731  6.457143e+06
#
# [1476 rows x 12 columns]

# %%
Lasso_data = pd.read_excel("Lasso.xlsx")
Lasso_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1727         купе    механика   350350  серебристый       2800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 1727  2.603845e+06
# 1728  1.051837e+07
# 1729  1.453791e+07
# 1730  2.015480e+07
# 1731  8.157713e+06

# %%
Lasso_data.shape
# Out:
# (1732, 12)

# %%
Lasso_data_normal = Lasso_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)")
Lasso_data_normal
# Out:
#       car_id     Mark              Model  Year  EngineSize     FuelType  \
# 0       2527     Land  Rover\tFreelander  2014         2.0       бензин
# 1       6141   Toyota            Corolla  2011         1.6       бензин
# 6       8576   Toyota              HiAce  2012         2.7       бензин
# 14      2416   Toyota              Yaris  2011         1.5       бензин
# 26      4663   Nissan            X-Trail  2016         2.0       бензин
# ...      ...      ...                ...   ...         ...          ...
# 1716     341   Toyota             Sienna  2010         2.7       бензин
# 1718    8169   Toyota            Corolla  2019         1.6       бензин
# 1725    6566  Hyundai            Genesis  2019         3.3       бензин
# 1727    3847      BMW                318  2002         1.9       бензин
# 1729    5003   Toyota      Land\tCruiser  2008         4.7   газ-бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 1            седан     автомат   137500        белый       5400000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 14           седан     автомат   170000        белый       5000000
# 26       кроссовер     автомат    70000       черный      10400000
# ...            ...         ...      ...          ...           ...
# 1716       минивэн     автомат   100000  серебристый       8500000
# 1718         седан   типтроник    20000  серебристый       9100000
# 1725         седан     автомат    47644       черный      14500000
# 1727          купе    механика   350350  серебристый       2800000
# 1729   внедорожник     автомат   263000        белый      14600000
#
#        predictions
# 0     9.728732e+06
# 1     5.078285e+06
# 6     9.319293e+06
# 14    4.437593e+06
# 26    1.055536e+07
# ...            ...
# 1716  9.065154e+06
# 1718  8.806216e+06
# 1725  1.440239e+07
# 1727  2.603845e+06
# 1729  1.453791e+07
#
# [387 rows x 12 columns]

# %%
Lasso_data_notnormal = Knn_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
Lasso_data_notnormal
# Out:
#       car_id        Mark              Model  Year  EngineSize     FuelType  \
# 0       2527        Land  Rover\tFreelander  2014         2.0       бензин
# 2       5268  Volkswagen               Golf  1997         1.8       бензин
# 3       7910      Subaru            Tribeca  2007         3.6       бензин
# 4       3182      Daewoo              Nexia  2013         1.5       бензин
# 5       3285     Porsche            Cayenne  2008         4.8       бензин
# ...      ...         ...                ...   ...         ...          ...
# 1726    3796      Toyota      Land\tCruiser  2012         4.6       бензин
# 1728    8630         ГАЗ       ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003      Toyota      Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902      Nissan             Patrol  2013         5.6       бензин
# 1731     313         Kia       Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 0       кроссовер     автомат    59000        синий       9700000
# 2         хэтчбек    механика   240000        синий       1700000
# 3       кроссовер     автомат   265983        белый       5250000
# 4           седан    механика   190000        белый       1640000
# 5       кроссовер   типтроник   109000      голубой       7600000
# ...           ...         ...      ...          ...           ...
# 1726  внедорожник     автомат   145000       черный      20800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 0     1.645000e+07
# 2     5.735714e+06
# 3     3.398571e+06
# 4     5.321429e+06
# 5     1.279857e+07
# ...            ...
# 1726  9.550000e+06
# 1728  4.888667e+06
# 1729  4.385714e+06
# 1730  2.780000e+06
# 1731  6.457143e+06
#
# [1476 rows x 12 columns]

# %%
Linear_data = pd.read_excel("Linear.xlsx")
Linear_data.tail()
# Out:
#       car_id    Mark          Model  Year  EngineSize     FuelType  \
# 1727    3847     BMW            318  2002         1.9       бензин
# 1728    8630     ГАЗ   ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003  Toyota  Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902  Nissan         Patrol  2013         5.6       бензин
# 1731     313     Kia   Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 1727         купе    механика   350350  серебристый       2800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 1727  2.603843e+06
# 1728  1.051837e+07
# 1729  1.453791e+07
# 1730  2.015481e+07
# 1731  8.157711e+06

# %%
Linear_data_normal = Linear_data.query("predictions < actual_price + (@value*actual_price) & predictions > actual_price - (@value*actual_price)")
Linear_data_normal
# Out:
#       car_id     Mark              Model  Year  EngineSize     FuelType  \
# 0       2527     Land  Rover\tFreelander  2014         2.0       бензин
# 1       6141   Toyota            Corolla  2011         1.6       бензин
# 6       8576   Toyota              HiAce  2012         2.7       бензин
# 14      2416   Toyota              Yaris  2011         1.5       бензин
# 26      4663   Nissan            X-Trail  2016         2.0       бензин
# ...      ...      ...                ...   ...         ...          ...
# 1716     341   Toyota             Sienna  2010         2.7       бензин
# 1718    8169   Toyota            Corolla  2019         1.6       бензин
# 1725    6566  Hyundai            Genesis  2019         3.3       бензин
# 1727    3847      BMW                318  2002         1.9       бензин
# 1729    5003   Toyota      Land\tCruiser  2008         4.7   газ-бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 1            седан     автомат   137500        белый       5400000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 14           седан     автомат   170000        белый       5000000
# 26       кроссовер     автомат    70000       черный      10400000
# ...            ...         ...      ...          ...           ...
# 1716       минивэн     автомат   100000  серебристый       8500000
# 1718         седан   типтроник    20000  серебристый       9100000
# 1725         седан     автомат    47644       черный      14500000
# 1727          купе    механика   350350  серебристый       2800000
# 1729   внедорожник     автомат   263000        белый      14600000
#
#        predictions
# 0     9.728731e+06
# 1     5.078285e+06
# 6     9.319293e+06
# 14    4.437593e+06
# 26    1.055536e+07
# ...            ...
# 1716  9.065155e+06
# 1718  8.806214e+06
# 1725  1.440239e+07
# 1727  2.603843e+06
# 1729  1.453791e+07
#
# [387 rows x 12 columns]

# %%
Linear_data_notnormal = Knn_data.query("predictions > actual_price + (@value*actual_price) | predictions < actual_price - (@value*actual_price)")
Linear_data_notnormal
# Out:
#       car_id        Mark              Model  Year  EngineSize     FuelType  \
# 0       2527        Land  Rover\tFreelander  2014         2.0       бензин
# 2       5268  Volkswagen               Golf  1997         1.8       бензин
# 3       7910      Subaru            Tribeca  2007         3.6       бензин
# 4       3182      Daewoo              Nexia  2013         1.5       бензин
# 5       3285     Porsche            Cayenne  2008         4.8       бензин
# ...      ...         ...                ...   ...         ...          ...
# 1726    3796      Toyota      Land\tCruiser  2012         4.6       бензин
# 1728    8630         ГАЗ       ГАЗель\tNEXT  2018         2.7       бензин
# 1729    5003      Toyota      Land\tCruiser  2008         4.7   газ-бензин
# 1730    4902      Nissan             Patrol  2013         5.6       бензин
# 1731     313         Kia       Cerato\tKoup  2012         2.0       бензин
#
#              Body GearboxType  Mileage        Color  actual_price  \
# 0       кроссовер     автомат    59000        синий       9700000
# 2         хэтчбек    механика   240000        синий       1700000
# 3       кроссовер     автомат   265983        белый       5250000
# 4           седан    механика   190000        белый       1640000
# 5       кроссовер   типтроник   109000      голубой       7600000
# ...           ...         ...      ...          ...           ...
# 1726  внедорожник     автомат   145000       черный      20800000
# 1728       фургон    механика   120000        белый       8499999
# 1729  внедорожник     автомат   263000        белый      14600000
# 1730  внедорожник     автомат   222128       черный      12820000
# 1731         купе   типтроник   100000  серебристый       4900000
#
#        predictions
# 0     1.645000e+07
# 2     5.735714e+06
# 3     3.398571e+06
# 4     5.321429e+06
# 5     1.279857e+07
# ...            ...
# 1726  9.550000e+06
# 1728  4.888667e+06
# 1729  4.385714e+06
# 1730  2.780000e+06
# 1731  6.457143e+06
#
# [1476 rows x 12 columns]

# %%
random_set = set(Random_forest_data_notnormal.car_id)
xgboost_set = set(XGboost_data_notnormal.car_id)
linear_set = set(Linear_data_notnormal.car_id)
lasso_set = set(Lasso_data_notnormal.car_id)
ridge_set = set(Ridge_data_notnormal.car_id)
knn_set = set(Knn_data_notnormal.car_id)

# print(len(random_set))
# print(len(xgboost_set))
# print(len(linear_set))
# print(len(lasso_set))
# print(len(ridge_set))
# print(len(knn_set))
print("Intersection:",len(knn_set.intersection(random_set,xgboost_set,linear_set,ridge_set,lasso_set)))
intersected_car_ids = knn_set.intersection(random_set,xgboost_set,linear_set,ridge_set,lasso_set)
df = pd.DataFrame({'car_id':list(intersected_car_ids)})

# print(A.intersection(B, C, D))
# Out:
# Intersection: 487

# %%
print(intersected_car_ids)
# Out:
# {2048, 8194, 8198, 8206, 6159, 8213, 6167, 24, 2074, 6170, 27, 6173, 33, 6178, 4134, 39, 6189, 4142, 6193, 8241, 6195, 49, 4152, 8256, 68, 69, 8263, 2122, 4171, 2123, 8268, 6223, 8273, 4177, 83, 2135, 6233, 6234, 4187, 6239, 2143, 6243, 2151, 4206, 111, 6257, 6258, 6262, 2167, 4214, 2175, 8324, 4230, 2184, 140, 8335, 4241, 4242, 4243, 149, 6301, 4254, 4256, 167, 2217, 2220, 173, 176, 2228, 6324, 6326, 4281, 6331, 8380, 4285, 8383, 8385, 8386, 4296, 6347, 6350, 4304, 6357, 4313, 6362, 6363, 8411, 6367, 6374, 6379, 8430, 8447, 257, 8455, 2312, 2313, 4377, 4380, 8478, 2337, 8482, 2343, 6441, 298, 8494, 2350, 6453, 313, 6458, 2377, 6491, 350, 8547, 4461, 6515, 6521, 4476, 6525, 2428, 4477, 8576, 8581, 392, 6537, 4493, 397, 8592, 4497, 403, 2457, 4505, 8602, 4509, 414, 421, 8618, 4525, 4527, 8624, 6582, 6586, 6591, 2504, 4555, 460, 2510, 8655, 2516, 6616, 4571, 2527, 6628, 4580, 6631, 6635, 6636, 6637, 6640, 4601, 4610, 526, 2575, 529, 4625, 6675, 4631, 2587, 2590, 554, 4651, 6701, 6703, 6704, 4657, 6720, 576, 4673, 6736, 4691, 6753, 6761, 620, 4718, 6766, 623, 4720, 4726, 6778, 4731, 2687, 2690, 2707, 4759, 663, 666, 2717, 6814, 4766, 6824, 6825, 6829, 706, 4807, 4808, 711, 4817, 2780, 6897, 4856, 2808, 769, 6915, 772, 773, 4877, 4881, 787, 2837, 4885, 4887, 6960, 817, 819, 2868, 837, 6982, 2892, 6993, 7000, 864, 7009, 4974, 7034, 4988, 903, 907, 2957, 5011, 7066, 924, 2974, 7074, 932, 7084, 7110, 3015, 7112, 5066, 7115, 5071, 976, 7125, 984, 5082, 5098, 1004, 3054, 1006, 5113, 5114, 7163, 5126, 1031, 3080, 7175, 5133, 3101, 7201, 1072, 1073, 3122, 1078, 5181, 5190, 7246, 1113, 5209, 3171, 7270, 7294, 3206, 7305, 1162, 5263, 3215, 7314, 1173, 7317, 5274, 7323, 1196, 3245, 3244, 3247, 7343, 7348, 7352, 5307, 5313, 1219, 7365, 5319, 1233, 7379, 5331, 3285, 7383, 7393, 7402, 1260, 3316, 7416, 7424, 1287, 7434, 1294, 1302, 7470, 7472, 3388, 3390, 1344, 5442, 5447, 7496, 5451, 3412, 7513, 7514, 5466, 3421, 3424, 3427, 5475, 1388, 7534, 7538, 1399, 5500, 1405, 5505, 3457, 3461, 3465, 7563, 5528, 5529, 1436, 1439, 3489, 5538, 3493, 5556, 3514, 1482, 7627, 3535, 1501, 5604, 7654, 1513, 5619, 3575, 5624, 3577, 7676, 5632, 7681, 5636, 7685, 3592, 3607, 3611, 5659, 1563, 3615, 7728, 1587, 7742, 1600, 5697, 7754, 5715, 1630, 1635, 3687, 1646, 3695, 7791, 3732, 7829, 7830, 3735, 5780, 3737, 5789, 1694, 7851, 7854, 3765, 7867, 3774, 1735, 5835, 5841, 7898, 7899, 5854, 3808, 5857, 5860, 1770, 5867, 3823, 5874, 3826, 1779, 7930, 5883, 5888, 3842, 5903, 5909, 7968, 1826, 5923, 3879, 7975, 7991, 1848, 1851, 3903, 7999, 5954, 3912, 1865, 5968, 5969, 5974, 1887, 8035, 8037, 8041, 6014, 3969, 8077, 1934, 6037, 8086, 6057, 1962, 8107, 4018, 1972, 8118, 8119, 1974, 4026, 6076, 8125, 8127, 4032, 6081, 4033, 4035, 1988, 8133, 1992, 4041, 4044, 6094, 4050, 8148, 2004, 4057, 4059, 6107, 8163, 6120, 6121, 6126, 6131, 8179, 8181, 6135, 2041, 8186}

# %%
print(df)
# Out:
#      car_id
# 0      2048
# 1      8194
# 2      8198
# 3      8206
# 4      6159
# ..      ...
# 482    8179
# 483    8181
# 484    6135
# 485    2041
# 486    8186
#
# [487 rows x 1 columns]

# %%
intersected_sel = XGboost_data_notnormal[XGboost_data_notnormal.car_id.isin(intersected_car_ids)]
intersected_sel
# Out:
#       car_id           Mark              Model  Year  EngineSize FuelType  \
# 0       2527           Land  Rover\tFreelander  2014         2.0   бензин
# 5       3285        Porsche            Cayenne  2008         4.8   бензин
# 6       8576         Toyota              HiAce  2012         2.7   бензин
# 12      4285  Mercedes-Benz             S\t450  2006         4.5   бензин
# 16      7084            BMW                 X6  2012         4.4   бензин
# ...      ...            ...                ...   ...         ...      ...
# 1710    1302          Lexus            GX\t460  2013         4.6   бензин
# 1717    4230            Kia              Cee’d  2013         1.6   бензин
# 1719    8181         Toyota      Land\tCruiser  2015         4.6   бензин
# 1724     526     Volkswagen        Transporter  2007         2.5   дизель
# 1731     313            Kia       Cerato\tKoup  2012         2.0   бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 0        кроссовер     автомат    59000        синий       9700000
# 5        кроссовер   типтроник   109000      голубой       7600000
# 6     микроавтобус    механика   226000  серебристый       8900000
# 12           седан     автомат   293196  серебристый       7000000
# 16       кроссовер   типтроник    76000       черный      10500000
# ...            ...         ...      ...          ...           ...
# 1710   внедорожник   типтроник   107000       черный      16999999
# 1717       хэтчбек   типтроник   253000   коричневый       5144000
# 1719   внедорожник     автомат    49700        белый      32500000
# 1724       минивэн    механика   173000        белый       8000000
# 1731          купе   типтроник   100000  серебристый       4900000
#
#       predictions
# 0      14644404.0
# 5       8628735.0
# 6      10275888.0
# 12      5823991.5
# 16     16097132.0
# ...           ...
# 1710   21498130.0
# 1717    4256721.0
# 1719   26162330.0
# 1724    4772302.0
# 1731    6880113.5
#
# [487 rows x 12 columns]

# %%
df = pd.DataFrame(intersected_sel[intersected_sel.Mark =='Toyota'])
df
# Out:
#       car_id    Mark                 Model  Year  EngineSize     FuelType  \
# 6       8576  Toyota                 HiAce  2012         2.7       бензин
# 82      6640  Toyota             Carina\tE  1993         2.0       бензин
# 102     8618  Toyota  Land\tCruiser\tPrado  1998         3.0       дизель
# 144     2457  Toyota  Land\tCruiser\tPrado  1997         3.4       бензин
# 189     6326  Toyota               4Runner  2018         4.0       бензин
# 191     7754  Toyota                 Yaris  2008         1.3       бензин
# 202     3171  Toyota               Alphard  2004         2.4   газ-бензин
# 259     6094  Toyota                Tacoma  2008         4.0       бензин
# 274     3687  Toyota                RAV\t4  2007         2.0       бензин
# 297     7125  Toyota                 Camry  1999         2.2       бензин
# 300     4731  Toyota                RAV\t4  2015         2.5       бензин
# 326     4601  Toyota                 Venza  2012         2.7       бензин
# 374     1031  Toyota  Land\tCruiser\tPrado  2013         2.7       бензин
# 383     8118  Toyota               Corolla  2007         1.6       бензин
# 399     1501  Toyota         Land\tCruiser  2008         4.7       бензин
# 401     8256  Toyota                 Camry  2020         2.5       бензин
# 413     5133  Toyota                 Camry  2004         2.4       бензин
# 438     3842  Toyota                RAV\t4  2016         2.0       бензин
# 468     2143  Toyota                 Camry  2012         2.5       бензин
# 472     4313  Toyota                 Camry  2012         2.5   газ-бензин
# 505     5082  Toyota                 Camry  2007         2.4   газ-бензин
# 519     3015  Toyota                Tundra  2004         4.7       бензин
# 559      706  Toyota         Land\tCruiser  2006         4.7       бензин
# 568     1173  Toyota                 Camry  2018         2.5       бензин
# 612     6350  Toyota            Highlander  2019         3.5       бензин
# 627     1482  Toyota                 Camry  2007         2.4       бензин
# 769     2228  Toyota        Avensis\tVerso  2002         2.0       бензин
# 804     8125  Toyota                Avalon  2007         3.5       бензин
# 827     4651  Toyota                 Camry  2003         2.4   газ-бензин
# 839     5604  Toyota  Land\tCruiser\tPrado  2015         2.7       бензин
# 898     2504  Toyota                 Camry  2005         2.4   газ-бензин
# 903       27  Toyota         Land\tCruiser  2004         4.7   газ-бензин
# 962     3122  Toyota                RAV\t4  2016         2.0       бензин
# 966      623  Toyota                Solara  2000         2.2       бензин
# 971     7365  Toyota                 Camry  2020         2.0       бензин
# 974     8380  Toyota                 Camry  2005         2.4       бензин
# 992     3316  Toyota                Celica  2002         1.8       бензин
# 1024    7294  Toyota               Corolla  1992         1.6       бензин
# 1076    4625  Toyota         Camry\tGracia  1997         2.2       бензин
# 1081    2004  Toyota         Land\tCruiser  2014         4.7       бензин
# 1089    8186  Toyota                 Camry  2011         2.5       бензин
# 1104    8086  Toyota                Avalon  1997         3.0       бензин
# 1144    8482  Toyota                 Camry  2011         2.5       бензин
# 1153    2974  Toyota                Tundra  2012         5.7       бензин
# 1193     554  Toyota                 Camry  1994         1.6       бензин
# 1213    5066  Toyota               Avensis  2001         1.8       бензин
# 1240    2428  Toyota                Previa  1992         2.4       бензин
# 1244    4142  Toyota                 Camry  2008         3.5   газ-бензин
# 1276    6357  Toyota            Highlander  2019         3.5       бензин
# 1361     976  Toyota               Avensis  2013         2.0       бензин
# 1449    2343  Toyota                 Camry  2016         2.5       бензин
# 1450    5528  Toyota              Fortuner  2012         2.7       бензин
# 1488    5903  Toyota         Land\tCruiser  2014         4.2       дизель
# 1490    4134  Toyota            Highlander  2019         2.7       бензин
# 1509     576  Toyota               Alphard  2005         3.0   газ-бензин
# 1535    1563  Toyota                 Camry  2014         2.5       бензин
# 1578     666  Toyota                 Camry  2013         2.5       бензин
# 1701    6703  Toyota                 Camry  2000         2.2       бензин
# 1719    8181  Toyota         Land\tCruiser  2015         4.6       бензин
#
#               Body GearboxType  Mileage        Color  actual_price  \
# 6     микроавтобус    механика   226000  серебристый       8900000
# 82         хэтчбек    механика   402162     бордовый       1900000
# 102    внедорожник     автомат   123456        синий       4800000
# 144    внедорожник    механика   353000        белый       3599000
# 189    внедорожник     автомат    35398       черный      16300000
# 191          седан     автомат   284894        белый       4190000
# 202        минивэн     автомат   250000        белый       3450000
# 259          пикап     автомат   209214        серый      13000000
# 274      кроссовер     автомат   145000       черный       7300000
# 297          седан     автомат  1600000        серый       1750000
# 300      кроссовер     автомат    60000        белый      14300000
# 326      кроссовер     автомат    92000        серый       9500000
# 374    внедорожник     автомат   180000        белый      15000000
# 383          седан     автомат   168200        серый       5300000
# 399    внедорожник     автомат   100000        белый      19000000
# 401          седан     автомат     7000       черный      13300000
# 413          седан     автомат   427000  серебристый       3899000
# 438      кроссовер   типтроник    51000       черный      10700000
# 468          седан     автомат   110000        белый      11000000
# 472          седан   типтроник    89000       черный       6500000
# 505          седан     автомат   180000        синий       4600000
# 519          пикап     автомат   200000        белый       5900000
# 559    внедорожник     автомат   303362       черный       8800000
# 568          седан     автомат    21000        белый       8500000
# 612      кроссовер     автомат    24344        серый      16500000
# 627          седан     автомат   154496  серебристый       6500000
# 769        минивэн    механика   244000  серебристый       4700000
# 804          седан     автомат   161934       черный       4300000
# 827          седан     автомат   360000       черный       5000000
# 839    внедорожник     автомат    65600       черный      17700000
# 898          седан     автомат   284914        белый       3800000
# 903    внедорожник     автомат   346000  серебристый       7400000
# 962      кроссовер     автомат    84000       черный      14777777
# 966           купе    механика   341180  серебристый       1950000
# 971          седан     автомат     5000        белый      12000000
# 974          седан     автомат   292000        белый       5700000
# 992           купе     автомат   276806  серебристый       2500000
# 1024       хэтчбек     автомат   470000        серый       1000000
# 1076     универсал     автомат   311000        белый       2200000
# 1081   внедорожник     автомат    95000        белый      26000000
# 1089         седан   типтроник   102700       черный       6550000
# 1104         седан     автомат   250000   золотистый       2000000
# 1144         седан     автомат   149000        белый       5500000
# 1153   внедорожник     автомат    46657       черный      46000000
# 1193         седан     автомат   252541  серебристый        950000
# 1213     универсал    механика   370000  серебристый       3350000
# 1240       минивэн     автомат    22222      красный       1700000
# 1244         седан     автомат    14000  серебристый       4200000
# 1276     кроссовер     автомат     3218       черный      16600000
# 1361         седан   типтроник   133000       черный       6100000
# 1449         седан     автомат    50000       черный      11200000
# 1450   внедорожник     автомат   115000  серебристый      10300000
# 1488       хардтоп    механика   129113        белый      15000000
# 1490     кроссовер     автомат    22000        белый      22000000
# 1509       минивэн     автомат   301000        белый       4250000
# 1535         седан     автомат   149057       черный       7699990
# 1578         седан   типтроник   144921       черный       6500000
# 1701         седан     автомат   320000        серый       2300000
# 1719   внедорожник     автомат    49700        белый      32500000
#
#        predictions
# 6     1.027589e+07
# 82    1.626820e+06
# 102   5.441435e+06
# 144   4.809228e+06
# 189   2.150139e+07
# 191   3.497830e+06
# 202   4.791722e+06
# 259   8.258376e+06
# 274   6.334390e+06
# 297   2.982621e+06
# 300   1.121468e+07
# 326   1.204329e+07
# 374   1.269180e+07
# 383   4.566580e+06
# 399   1.401128e+07
# 401   1.507942e+07
# 413   4.524311e+06
# 438   1.387417e+07
# 468   8.253328e+06
# 472   8.430790e+06
# 505   5.342130e+06
# 519   7.813548e+06
# 559   1.065860e+07
# 568   1.351742e+07
# 612   2.055192e+07
# 627   5.379028e+06
# 769   3.340973e+06
# 804   5.792966e+06
# 827   4.251375e+06
# 839   1.387215e+07
# 898   4.791792e+06
# 903   9.389378e+06
# 962   1.170823e+07
# 966   2.987802e+06
# 971   1.364848e+07
# 974   4.818174e+06
# 992   4.143622e+06
# 1024  1.938391e+06
# 1076  2.845652e+06
# 1081  2.217643e+07
# 1089  7.610044e+06
# 1104  2.887082e+06
# 1144  7.110792e+06
# 1153  2.557216e+07
# 1193  2.152806e+06
# 1213  2.623110e+06
# 1240  2.863917e+06
# 1244  5.726386e+06
# 1276  2.313431e+07
# 1361  7.495163e+06
# 1449  1.298449e+07
# 1450  1.206797e+07
# 1488  1.788967e+07
# 1490  1.721462e+07
# 1509  5.124774e+06
# 1535  8.861275e+06
# 1578  8.198647e+06
# 1701  2.987340e+06
# 1719  2.616233e+07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(50, 6))

plt.subplot(1,3,1)
plt1 = intersected_sel.Mark.value_counts().plot.bar()
plt.title('Cars Mark')
plt1.set(xlabel = 'Car Mark', ylabel='Frequency of mark')
# Out:
# [Text(0, 0.5, 'Frequency of mark'), Text(0.5, 0, 'Car Mark')]

# %%
plt.subplot(1,2,1)
plt.title("Mileage Spread")
sns.boxplot(y=intersected_sel.Mileage)

plt.subplot(1,2,2)
plt.title("Mileage Distribution Plot")
sns.distplot(intersected_sel.Mileage)


plt.show()

# %%
plt.figure(figsize=(25, 6))
plt.subplot(1,3,2)
plt1 = intersected_sel.FuelType.value_counts().plot.bar()
plt.title('Fuel Type Histogram')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,3)
plt1 = intersected_sel.Body.value_counts().plot.bar()
plt.title('Car Type Histogram')
plt1.set(xlabel = 'Car Type', ylabel='Frequency of Car type')

plt.show()

# %%
normal = Random_forest_data.GearboxType.value_counts()
normal
# Out:
# автомат      1007
# механика      446
# типтроник     191
# вариатор       78
# робот          10
# Name: GearboxType, dtype: int64

# %%
abnormal = intersected_sel.GearboxType.value_counts()
abnormal
# Out:
# автомат      231
# механика     189
# типтроник     50
# вариатор      14
# робот          3
# Name: GearboxType, dtype: int64

# %%
normal = Random_forest_data.Year.value_counts()
normal
# Out:
# 2014    160
# 2013    148
# 2007    142
# 2012    100
# 2019     96
# 2015     79
# 2008     76
# 2018     76
# 2006     76
# 2011     74
# 2005     52
# 2017     47
# 2004     45
# 2010     43
# 2003     41
# 2020     40
# 1992     39
# 2016     39
# 2002     39
# 2009     29
# 1995     29
# 1994     28
# 1997     27
# 2001     27
# 1999     27
# 1998     23
# 1996     22
# 1993     22
# 1991     22
# 2000     21
# 1990     18
# 1989     11
# 1988      5
# 2021      3
# 1987      1
# 1986      1
# 1984      1
# 1981      1
# 1973      1
# 1966      1
# Name: Year, dtype: int64

# %%
abnormal = intersected_sel.Year.value_counts()
abnormal
# Out:
# 2007    44
# 2013    38
# 2014    32
# 2008    24
# 2012    23
# 2015    20
# 2006    20
# 2018    19
# 2004    18
# 2019    18
# 2016    18
# 2011    17
# 1992    16
# 1995    15
# 1999    13
# 1994    13
# 2002    13
# 2020    11
# 2000    11
# 1993    11
# 2017    10
# 1998     9
# 2003     8
# 1991     8
# 1990     8
# 2001     7
# 2010     7
# 1989     7
# 1997     6
# 1996     6
# 1988     4
# 2005     4
# 2009     3
# 1984     1
# 1981     1
# 2021     1
# 1986     1
# 1987     1
# 1966     1
# Name: Year, dtype: int64
